# %%
# Import standard libraries
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
import pandas as pd

# %% [markdown]
# ### Part 1 – Scraping Italian Dishes

# %%
end_page_num = 2
i = 0
italian_dishes = []
italian_descriptors_ls = []


while i <= end_page_num:
    i +=1
    page = requests.get(f"https://www.allrecipes.com/recipes/723/world-cuisine/european/italian/?page={i}")
    italian = BeautifulSoup(page.content, "html.parser")
    _ = italian.find_all("article", class_="fixed-recipe-card")
    italian_dishes = italian.select('.fixed-recipe-card__title-link ')
    italian_descriptors = italian.select('.fixed-recipe-card__description')

# removes /n from names
italian_dishes_ls = [item.get_text().replace('\n', '') for item in italian_dishes]
italian_descriptors_ls = [item.get_text() for item in italian_descriptors]
italian_dishes_ls = list(OrderedDict.fromkeys(italian_dishes_ls))

# %%
italian_dishes_ls
# Out:
# ['Creamy Pesto Shrimp',
#  'Focaccia Bread',
#  'Tender Italian Baked Chicken',
#  'Tofu Parmigiana',
#  'Baked Ziti IV',
#  'Spaghetti Sauce with Ground Beef',
#  'Italian Dressing Mix',
#  'Pasta Pomodoro',
#  "Brooklyn Girl's Penne Arrabiata",
#  'Meatball Sandwich',
#  'Balsamic Bruschetta',
#  'Penne Pasta with Spinach and Bacon',
#  'Biscotti',
#  'Easy Pizza Sauce III',
#  'Toasted Garlic Bread',
#  'Pesto Pasta with Chicken',
#  'Stuffed Shells I',
#  'Slow Cooker Lasagna',
#  'Tacos in Pasta Shells',
#  'Bean Soup With Kale']

# %%
italian_df = pd.DataFrame({'dish':italian_dishes_ls,
                       'description':italian_descriptors_ls})
italian_df
# Out:
#                                   dish  \
# 0                  Creamy Pesto Shrimp
# 1                       Focaccia Bread
# 2         Tender Italian Baked Chicken
# 3                      Tofu Parmigiana
# 4                        Baked Ziti IV
# 5     Spaghetti Sauce with Ground Beef
# 6                 Italian Dressing Mix
# 7                       Pasta Pomodoro
# 8      Brooklyn Girl's Penne Arrabiata
# 9                    Meatball Sandwich
# 10                 Balsamic Bruschetta
# 11  Penne Pasta with Spinach and Bacon
# 12                            Biscotti
# 13                Easy Pizza Sauce III
# 14                Toasted Garlic Bread
# 15            Pesto Pasta with Chicken
# 16                    Stuffed Shells I
# 17                 Slow Cooker Lasagna
# 18               Tacos in Pasta Shells
# 19                 Bean Soup With Kale
#
#                                           description
# 0   Butter, cream, Parmesan cheese and pesto conve...
# 1   A wonderful, quick alternative to garlic bread...
# 2   This baked chicken recipe is ready in just 30 ...
# 3   Breaded tofu a la parmigiana. You'll just abou...
# 4   Ziti pasta is layered with Provolone, mozzarel...
# 5   Rich and meaty spaghetti sauce is surprisingly...
# 6   This Italian dressing mix is a combination of ...
# 7   Easy and light pasta with tomatoes and garlic....
# 8   I created this easy Italian chicken breast rec...
# 9   Meatballs in tomato sauce with melted cheese o...
# 10  Balsamic vinegar adds a delicious zip to easy ...
# 11  This is a quick light meal. Wilted spinach, ba...
# 12  This is a simple, no frills biscotti. My frien...
# 13  Quick and easy pizza sauce. No cooking and qui...
# 14  Quick and scrumptious garlic bread that will c...
# 15  Easy and delicious bowtie pasta with chicken, ...
# 16  A creamy blend of cottage cheese, mozzarella, ...
# 17  Start with a skillet and finish with a slow co...
# 18  Jumbo pasta shells stuffed with a rich, spicy ...
# 19  White beans, cannellini or navy, and chicken b...

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### 2nd attempt (Dominik) // different website / JS scraping

# %%
import urllib.request
from bs4 import BeautifulSoup
import csv
import urllib.request
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver import Firefox
pd.set_option('display.max_colwidth', 0)

# %%
#! pip install beatifulsoup
#! pip install geckodriver

# %% [markdown]
# Warning: I installed geckodriver with Homebrew (brew install geckodriver)

# %%
del data
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8617337b4a8b> in <module>
# ----> 1 del data
#       2 del df
#
# NameError: name 'data' is not defined

# %%
# open browser and create empty data array
from time import sleep
from datetime import datetime

driver = webdriver.Firefox(executable_path="/usr/local/bin/geckodriver")
data = []

start_time = datetime.now()

# scrape (start with page 2)
for i in range(2,4):
    urlpage = (f"http://allrecipes.co.uk/recipes/indian-recipes.aspx?page={i}&o_is=LV_Pgntn")
    driver.get(urlpage)
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    time.sleep(5)
    results = driver.find_elements_by_xpath('//*[@id="sectionTopRecipes"]//*[@class="row recipe"]')
    for result in results:
        product_name = result.find_element_by_tag_name("h3").text
        description = result.find_element_by_class_name("js-truncate").text
        data.append({"product" : product_name, "description": description})
    print(f"Number of scraped recipes: {len(data)}")
    i =+ 1
    
stop_time = datetime.now()
elapsed_time = stop_time - start_time
print(f"Finished! Scraped {len(data)} recipes in total.")
print(f"Elapsed Time: {elapsed_time}")
# Out:
# Number of scraped recipes: 10
# Number of scraped recipes: 20
# Finished! Scraped 20 recipes in total.
# Elapsed Time: 0:00:22.553039

# %%
# Show results

df = pd.DataFrame(data)
df
# Out:
#                                                         product  \
# 0   Myree's Chicken Madras
# 1   Chicken Jalfrezi slow cooker
# 2   Fruity chicken curry
# 3   Slow cooked chicken korma\n►
# 4   Quick vegetable curry
# 5   Easy chicken curry
# 6   Baked onion bhajis
# 7   Fluffy Naan Bread
# 8   Spiced onions
# 9   Masoor dhal curry
# 10  Ultimate chicken curry
# 11  Murgh kari (Indian chicken curry with tomatoes and yoghurt)
# 12  Indian lamb or beef keema
