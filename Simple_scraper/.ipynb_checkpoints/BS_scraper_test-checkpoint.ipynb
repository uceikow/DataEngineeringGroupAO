# %%
# Import standard libraries
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
import pandas as pd

# %% [markdown]
# ### Scraping

# %%
import urllib.request
from bs4 import BeautifulSoup
import csv
import urllib.request
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver import Firefox
pd.set_option('display.max_colwidth', 0)

# %%
#! pip install beatifulsoup
#! pip install geckodriver

# %% [markdown]
# Warning: I installed geckodriver with Homebrew (brew install geckodriver)

# %%
# open browser and create empty data array

from time import sleep
from datetime import datetime

driver = webdriver.Firefox(executable_path="/usr/local/bin/geckodriver")
data = []

# %%
# scrape indian

start_time = datetime.now()

# scrape (start with page 2)
for i in range(2,90):
    urlpage = (f"http://allrecipes.co.uk/recipes/indian-recipes.aspx?page={i}&o_is=LV_Pgntn")
    driver.get(urlpage)
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    time.sleep(5)
    results = driver.find_elements_by_xpath('//*[@id="sectionTopRecipes"]//*[@class="row recipe"]')
    for result in results:
        product_name = result.find_element_by_tag_name("h3").text
        description = result.find_element_by_class_name("js-truncate").text
        data.append({"product" : product_name, "description": description, "cuisine": "indian"})
    print(f"Number of scraped recipes: {len(data)}")
    i =+ 1
    
stop_time = datetime.now()
elapsed_time = stop_time - start_time
print(f"Finished! Scraped {len(data)} recipes in total.")
print(f"Elapsed Time: {elapsed_time}")
# Out:
# Number of scraped recipes: 10
# Number of scraped recipes: 20
# Number of scraped recipes: 30
# Number of scraped recipes: 40
# Number of scraped recipes: 50
# Number of scraped recipes: 60
# Number of scraped recipes: 70
# Number of scraped recipes: 80
# Number of scraped recipes: 90
# Number of scraped recipes: 100
# Number of scraped recipes: 110
# Number of scraped recipes: 120
# Number of scraped recipes: 130
# Number of scraped recipes: 140
# Number of scraped recipes: 150
# Number of scraped recipes: 160
# Number of scraped recipes: 170
# Number of scraped recipes: 180
# Number of scraped recipes: 190
# Number of scraped recipes: 200
# Number of scraped recipes: 210
# Number of scraped recipes: 220
# Number of scraped recipes: 230
# Number of scraped recipes: 240
# Number of scraped recipes: 250
# Number of scraped recipes: 260
# Number of scraped recipes: 270
# Number of scraped recipes: 280
# Number of scraped recipes: 290
# Number of scraped recipes: 300
# Number of scraped recipes: 310
# Number of scraped recipes: 320
# Number of scraped recipes: 330
# Number of scraped recipes: 340
# Number of scraped recipes: 350
# Number of scraped recipes: 360
# Number of scraped recipes: 370
# Number of scraped recipes: 380
# Number of scraped recipes: 390
# Number of scraped recipes: 400
# Number of scraped recipes: 410
# Number of scraped recipes: 420
# Number of scraped recipes: 430
# Number of scraped recipes: 440
# Number of scraped recipes: 450
# Number of scraped recipes: 460
# Number of scraped recipes: 470
# Number of scraped recipes: 480
# Number of scraped recipes: 490
# Number of scraped recipes: 500
# Number of scraped recipes: 510
# Number of scraped recipes: 520
# Number of scraped recipes: 530
# Number of scraped recipes: 540
# Number of scraped recipes: 550
# Number of scraped recipes: 560
# Number of scraped recipes: 570
# Number of scraped recipes: 580
# Number of scraped recipes: 590
# Number of scraped recipes: 600
# Number of scraped recipes: 610
# Number of scraped recipes: 620
# Number of scraped recipes: 630
# Number of scraped recipes: 640
# Number of scraped recipes: 650
# Number of scraped recipes: 660
# Number of scraped recipes: 670
# Number of scraped recipes: 680
# Number of scraped recipes: 690
# Number of scraped recipes: 700
# Number of scraped recipes: 710
# Number of scraped recipes: 720
# Number of scraped recipes: 730
# Number of scraped recipes: 740
# Number of scraped recipes: 750
# Number of scraped recipes: 760
# Number of scraped recipes: 770
# Number of scraped recipes: 780
# Number of scraped recipes: 790
# Number of scraped recipes: 800
# Number of scraped recipes: 810
# Number of scraped recipes: 820
# Number of scraped recipes: 830
# Number of scraped recipes: 840
# Number of scraped recipes: 850
# Number of scraped recipes: 860
# Number of scraped recipes: 870
# Number of scraped recipes: 880
# Finished! Scraped 880 recipes in total.
# Elapsed Time: 0:17:08.820717

# %%
# scrape mexican

start_time = datetime.now()

# scrape (start with page 2)
for i in range(2,60):
    urlpage = (f"http://allrecipes.co.uk/recipes/mexican-recipes.aspx?page={i}&o_is=LV_Pgntn")
    driver.get(urlpage)
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    time.sleep(5)
    results = driver.find_elements_by_xpath('//*[@id="sectionTopRecipes"]//*[@class="row recipe"]')
    for result in results:
        product_name = result.find_element_by_tag_name("h3").text
        description = result.find_element_by_class_name("js-truncate").text
        data.append({"product" : product_name, "description": description, "cuisine": "mexican"})
    print(f"Number of scraped recipes: {len(data)}")
    i =+ 1
    
stop_time = datetime.now()
elapsed_time = stop_time - start_time
print(f"Finished! Scraped {len(data)} recipes in total.")
print(f"Elapsed Time: {elapsed_time}")
# Out:
# Number of scraped recipes: 890
# Number of scraped recipes: 900
# Number of scraped recipes: 910
# Number of scraped recipes: 920
# Number of scraped recipes: 930
# Number of scraped recipes: 940
# Number of scraped recipes: 950
# Number of scraped recipes: 960
# Number of scraped recipes: 970
# Number of scraped recipes: 980
# Number of scraped recipes: 990
# Number of scraped recipes: 1000
# Number of scraped recipes: 1010
# Number of scraped recipes: 1020
# Number of scraped recipes: 1030
# Number of scraped recipes: 1040
# Number of scraped recipes: 1050
# Number of scraped recipes: 1060
# Number of scraped recipes: 1070
# Number of scraped recipes: 1080
# Number of scraped recipes: 1090
# Number of scraped recipes: 1100
# Number of scraped recipes: 1110
# Number of scraped recipes: 1120
# Number of scraped recipes: 1130
# Number of scraped recipes: 1140
# Number of scraped recipes: 1150
# Number of scraped recipes: 1160
# Number of scraped recipes: 1170
# Number of scraped recipes: 1180
# Number of scraped recipes: 1190
# Number of scraped recipes: 1200
# Number of scraped recipes: 1210
# Number of scraped recipes: 1220
# Number of scraped recipes: 1230
# Number of scraped recipes: 1240
# Number of scraped recipes: 1250
# Number of scraped recipes: 1260
# Number of scraped recipes: 1270
# Number of scraped recipes: 1280
# Number of scraped recipes: 1290
# Number of scraped recipes: 1300
# Number of scraped recipes: 1310
# Number of scraped recipes: 1320
# Number of scraped recipes: 1330
# Number of scraped recipes: 1340
# Number of scraped recipes: 1350
# Number of scraped recipes: 1360
# Number of scraped recipes: 1370
# Number of scraped recipes: 1380
# Number of scraped recipes: 1390
# Number of scraped recipes: 1400
# Number of scraped recipes: 1410
# Number of scraped recipes: 1420
# Number of scraped recipes: 1430
# Number of scraped recipes: 1440
# Number of scraped recipes: 1450
# Number of scraped recipes: 1460
# Finished! Scraped 1460 recipes in total.
# Elapsed Time: 0:11:25.771251

# %%
# scrape italian

start_time = datetime.now()

# scrape (start with page 2)
for i in range(2,90):
    urlpage = (f"http://allrecipes.co.uk/recipes/italian-recipes.aspx?page={i}&o_is=LV_Pgntn")
    driver.get(urlpage)
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    time.sleep(5)
    results = driver.find_elements_by_xpath('//*[@id="sectionTopRecipes"]//*[@class="row recipe"]')
    for result in results:
        product_name = result.find_element_by_tag_name("h3").text
        description = result.find_element_by_class_name("js-truncate").text
        data.append({"product" : product_name, "description": description, "cuisine": "italian"})
    print(f"Number of scraped recipes: {len(data)}")
    i =+ 1
    
stop_time = datetime.now()
elapsed_time = stop_time - start_time
print(f"Finished! Scraped {len(data)} recipes in total.")
print(f"Elapsed Time: {elapsed_time}")
# Out:
# Number of scraped recipes: 1470
# Number of scraped recipes: 1480
# Number of scraped recipes: 1490
# Number of scraped recipes: 1500
# Number of scraped recipes: 1510
# Number of scraped recipes: 1520
# Number of scraped recipes: 1530
# Number of scraped recipes: 1540
# Number of scraped recipes: 1550
# Number of scraped recipes: 1560
# Number of scraped recipes: 1570
# Number of scraped recipes: 1580
# Number of scraped recipes: 1590
# Number of scraped recipes: 1600
# Number of scraped recipes: 1610
# Number of scraped recipes: 1620
# Number of scraped recipes: 1630
# Number of scraped recipes: 1640
# Number of scraped recipes: 1650
# Number of scraped recipes: 1660
# Number of scraped recipes: 1670
# Number of scraped recipes: 1680
# Number of scraped recipes: 1690
# Number of scraped recipes: 1700
# Number of scraped recipes: 1710
# Number of scraped recipes: 1720
# Number of scraped recipes: 1730
# Number of scraped recipes: 1740
# Number of scraped recipes: 1750
# Number of scraped recipes: 1760
# Number of scraped recipes: 1770
# Number of scraped recipes: 1780
# Number of scraped recipes: 1790
# Number of scraped recipes: 1800
# Number of scraped recipes: 1810
# Number of scraped recipes: 1820
# Number of scraped recipes: 1830
# Number of scraped recipes: 1840
# Number of scraped recipes: 1850
# Number of scraped recipes: 1860
# Number of scraped recipes: 1870
# Number of scraped recipes: 1880
# Number of scraped recipes: 1890
# Number of scraped recipes: 1900
# Number of scraped recipes: 1910
# Number of scraped recipes: 1920
# Number of scraped recipes: 1930
# Number of scraped recipes: 1940
# Number of scraped recipes: 1950
# Number of scraped recipes: 1960
# Number of scraped recipes: 1970
# Number of scraped recipes: 1980
# Number of scraped recipes: 1990
# Number of scraped recipes: 2000
# Number of scraped recipes: 2010
# Number of scraped recipes: 2020
# Number of scraped recipes: 2030
# Number of scraped recipes: 2040
# Number of scraped recipes: 2050
# Number of scraped recipes: 2060
# Number of scraped recipes: 2070
# Number of scraped recipes: 2080
# Number of scraped recipes: 2090
# Number of scraped recipes: 2100
# Number of scraped recipes: 2110
# Number of scraped recipes: 2120
# Number of scraped recipes: 2130
# Number of scraped recipes: 2140
# Number of scraped recipes: 2150
# Number of scraped recipes: 2160
# Number of scraped recipes: 2170
# Number of scraped recipes: 2180
# Number of scraped recipes: 2190
# Number of scraped recipes: 2200
# Number of scraped recipes: 2210
# Number of scraped recipes: 2220
# Number of scraped recipes: 2230
# Number of scraped recipes: 2240
# Number of scraped recipes: 2250
# Number of scraped recipes: 2260
# Number of scraped recipes: 2270
# Number of scraped recipes: 2280
# Number of scraped recipes: 2290
# Number of scraped recipes: 2300
# Number of scraped recipes: 2310
# Number of scraped recipes: 2320
# Number of scraped recipes: 2330
# Number of scraped recipes: 2340
# Finished! Scraped 2340 recipes in total.
# Elapsed Time: 0:17:09.125720

# %%
# Show results and DON'T clean

df1 = pd.DataFrame(data)
df1.columns = ["Title", "Description", "label"]
df1
# Out:
#                                                                    Title  \
# 0     Myree's Chicken Madras
# 1     Chicken Jalfrezi slow cooker
# 2     Fruity chicken curry
# 3     Slow cooked chicken korma\n►
# 4     Quick vegetable curry
# ...                     ...
# 2335  Sicilian aubergine and rigatoni pasta bake
# 2336  Meaty spinach lasagne with béchamel sauce (Lasagne verdi al forno)
# 2337  Italian Stuffed Chicken
# 2338  Sicilian Almond Biscuits
# 2339  Fusilli alla Siciliana
#
#                                                                                                                                                                                                               Description  \
# 0     There is nothing quite like authentic Indian food prepared using a traditional recipe. This dish is a must for those of you who enjoy a good old curry. You can cook this curry in the morning and leave it [...]
# 1     This is really simple with no need to marinate. Can make it as hot as you want - although Jalfrezi is normally medium hot. Just put all the ingredients in the slow cooker and enjoy the smells throughout [...]
# 2     A delicious but simple fruity curry recipe. Serves two hungry people.
# 3     This mild, delicately fragrant curry has a rich creamy sauce that sure to be a winner. Serve with plain boiled rice or warm naan bread.
# 4     A quick, healthy and comforting supper fix after a long day's work. Serve with rice or naan. Also great as a jacket potato topping!
# ...                                                                                                                                   ...
# 2335  A quick way to make a pasta bake with rigatoni and aubergine. You could use your favourite tomato pasta sauce instead of the passata.
# 2336  An especially lovely and hearty lasagne. The gorgeous green colour and flavour of spinach lasagne sheets layered with minces of pork, beef and ham as well as beautifully earthy chicken livers and salty [...]
# 2337  This roast chicken dish has the perfect combination of flavours and textures. Pesto coated chicken thighs are stuffed with aubergine, red pepper, spring onion and mozzarella, then wrapped in prosciutto [...]
# 2338  These crunchy and delicious biscuits are inspired by the quaresimali (lenten biscuits), which were traditionally made during Lent. However, this version contains both eggs and butter. They can of course be [...]
# 2339  An all time classic Sicilian pasta recipe, this dish is rich and tasty. Cubes of aubergine are fried until golden, then tossed with cherry tomatoes, salty ricotta, fresh basil and fusilli pasta.
#
#         label
# 0     indian
# 1     indian
# 2     indian
# 3     indian
# 4     indian
# ...      ...
# 2335  italian
# 2336  italian
# 2337  italian
# 2338  italian
# 2339  italian
#
# [2340 rows x 3 columns]

# %%
df.to_csv("final_scrape_not_cleaned.csv", encoding='utf-8', index=False)

# %%
# Show results and clean

df = pd.DataFrame(data)
df.columns = ["Title", "Description", "label"]
df['Title'] = df['Title'].replace('►', '', regex=True)
df['Title'].replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
df = df.replace(to_replace= '\.', value= '', regex=True)
df = df.replace(to_replace= '\[', value= '', regex=True)
df = df.replace(to_replace= '\]', value= '', regex=True)
df = df.replace(to_replace= '\?', value= '', regex=True)
df = df.replace(to_replace= '\!', value= '', regex=True)
df
# Out:
#                                                                    Title  \
# 0     Myree's Chicken Madras
# 1     Chicken Jalfrezi slow cooker
# 2     Fruity chicken curry
# 3     Slow cooked chicken korma
# 4     Quick vegetable curry
# ...                     ...
# 2335  Sicilian aubergine and rigatoni pasta bake
# 2336  Meaty spinach lasagne with béchamel sauce (Lasagne verdi al forno)
# 2337  Italian Stuffed Chicken
# 2338  Sicilian Almond Biscuits
# 2339  Fusilli alla Siciliana
#
#                                                                                                                                                                                                        Description  \
# 0     There is nothing quite like authentic Indian food prepared using a traditional recipe This dish is a must for those of you who enjoy a good old curry You can cook this curry in the morning and leave it
# 1     This is really simple with no need to marinate Can make it as hot as you want - although Jalfrezi is normally medium hot Just put all the ingredients in the slow cooker and enjoy the smells throughout
# 2     A delicious but simple fruity curry recipe Serves two hungry people
# 3     This mild, delicately fragrant curry has a rich creamy sauce that sure to be a winner Serve with plain boiled rice or warm naan bread
# 4     A quick, healthy and comforting supper fix after a long day's work Serve with rice or naan Also great as a jacket potato topping
# ...                                                                                                                                ...
# 2335  A quick way to make a pasta bake with rigatoni and aubergine You could use your favourite tomato pasta sauce instead of the passata
# 2336  An especially lovely and hearty lasagne The gorgeous green colour and flavour of spinach lasagne sheets layered with minces of pork, beef and ham as well as beautifully earthy chicken livers and salty
# 2337  This roast chicken dish has the perfect combination of flavours and textures Pesto coated chicken thighs are stuffed with aubergine, red pepper, spring onion and mozzarella, then wrapped in prosciutto
# 2338  These crunchy and delicious biscuits are inspired by the quaresimali (lenten biscuits), which were traditionally made during Lent However, this version contains both eggs and butter They can of course be
# 2339  An all time classic Sicilian pasta recipe, this dish is rich and tasty Cubes of aubergine are fried until golden, then tossed with cherry tomatoes, salty ricotta, fresh basil and fusilli pasta
#
#         label
# 0     indian
# 1     indian
# 2     indian
# 3     indian
# 4     indian
# ...      ...
# 2335  italian
# 2336  italian
# 2337  italian
# 2338  italian
# 2339  italian
#
# [2340 rows x 3 columns]

# %%
# save results to a csv
df.to_csv("final_scrape_cleaned.csv", encoding='utf-8', index=False)

# %%
driver.quit()
